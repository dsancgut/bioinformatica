# %% [markdown]
# # MY FIRST NOTEBOOK TRAB 1 #

# %% [markdown]
# **COSAS QUE ESTOY APRENDIENDO DE CERO**

# %% [markdown]
# 1. Todo
# 2. Qué partes tiene un ordenador
# 3. Qué es una CPU
# 4. Qué es una tarjeta gráfica

# %% [markdown]
# **COSAS QUE TENGO QUE REPASAR EN CASA**

# %% [markdown]
# - Python
# - Gythub para extra puntos crearse una carpeta de cada
# - Readmid para subir archivos
# - tenemos que mandar el enlace con nuestro usuario

# %% [markdown]
# `mas deberes`

# %% [markdown]
# _descargar github_

# %% [markdown]
# #### **AHORA VAMOS A REALIZAR UNA OPERACIÓN CON LOS SGUIENTES NÚMEROS:**

# %%
numeros = [10,20,30,40,50]

# %%
media = sum(numeros) /len(numeros)

# %%
print(media)
# Out:
# 30.0

# %% [markdown]
# Cuando queremos ejecutar una función tenemos que cambiar de markdown a code porque ya es código, y las celdas se van enumerando.

# %%
from IPython.display import Image
Image("Supertubos_Surfer.jpg")
